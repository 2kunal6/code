# %% [markdown]
# <a href="https://colab.research.google.com/github/2kunal6/code/blob/master/ml/deep_learning/pytorch/torch_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim
import numpy as np
from sklearn import datasets

X_np, y_np = datasets.make_regression()
y_np = y_np.reshape(-1, 1).astype(np.float32)

x = torch.tensor(X_np, dtype=torch.float32)
y = torch.tensor(y_np, dtype=torch.float32)

model = torch.nn.Sequential(torch.nn.Linear(x.shape[1], y.shape[1]))

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)


for epoch in range(100):
  optimizer.zero_grad()
  y_pred = model(x)
  loss = loss_fn(y_pred, y)
  loss.backward()
  optimizer.step()
  print(loss)
# Out:
# tensor(28060.6367, grad_fn=<MseLossBackward>)
# tensor(28060.2852, grad_fn=<MseLossBackward>)
# tensor(28059.9297, grad_fn=<MseLossBackward>)
# tensor(28059.5801, grad_fn=<MseLossBackward>)
# tensor(28059.2266, grad_fn=<MseLossBackward>)
# tensor(28058.8750, grad_fn=<MseLossBackward>)
# tensor(28058.5195, grad_fn=<MseLossBackward>)
# tensor(28058.1641, grad_fn=<MseLossBackward>)
# tensor(28057.8125, grad_fn=<MseLossBackward>)
# tensor(28057.4648, grad_fn=<MseLossBackward>)
# tensor(28057.1074, grad_fn=<MseLossBackward>)
# tensor(28056.7578, grad_fn=<MseLossBackward>)
# tensor(28056.4043, grad_fn=<MseLossBackward>)
# tensor(28056.0527, grad_fn=<MseLossBackward>)
# tensor(28055.7031, grad_fn=<MseLossBackward>)
# tensor(28055.3496, grad_fn=<MseLossBackward>)
# tensor(28054.9980, grad_fn=<MseLossBackward>)
# tensor(28054.6426, grad_fn=<MseLossBackward>)
# tensor(28054.2930, grad_fn=<MseLossBackward>)
# tensor(28053.9355, grad_fn=<MseLossBackward>)
# ...
